# %%
import requests

for i in range(0,41):
    ii=i*20

    form_data='''find_key1:關鍵字
search_feature:
search_work:軟體專案主管+網路程式設計師+軟體工程師+通訊軟體工程師+演算法開發工程師+系統規劃分析師+其他資訊專業人員
search_multi_loc:請選擇地區
find_key2:
search_multi_loc2:請選擇地區
search_work2:請選擇職務
search_job2:請選擇行業
find_key3:
search_multi_loc3:請選擇地區
search_work3:請選擇職務
_rdo_1:1
search_subj:
search_work4:請選擇職務
search_multi_loc4:請選擇地區
search_multi_loc5:請選擇地區
_rdo_2:1
search_work6:
search_work7:請選擇職務
search_multi_loc6:請選擇地區
search_work8:請選擇職務
search_multi_loc7:請選擇地區
find_sf_subj_mode1:
s_find_sf_subj_mode1:
find_se_work_mode1:
s_find_se_work_mode1:
find_zone_mode1:
find_zone_mode2:
find_zone_mode3:
find_zone_mode4:
find_zone_mode5:
find_zone_mode6:
find_zone_mode7:
find_zone_mode8:
find_zone_mode9:
find_zone_mode10:
s_find_zone_mode1:
s_find_zone_mode2:
s_find_zone_mode3:
s_find_zone_mode4:
s_find_zone_mode5:
s_find_zone_mode6:
s_find_zone_mode7:
s_find_zone_mode8:
s_find_zone_mode9:
s_find_zone_mode10:
find_metro_mode1:
find_metro_mode2:
find_metro_mode3:
find_metro_mode4:
find_metro_mode5:
find_metro_mode6:
find_metro_mode7:
find_metro_mode8:
find_metro_mode9:
find_metro_mode10:
s_find_metro_mode1:
s_find_metro_mode2:
s_find_metro_mode3:
s_find_metro_mode4:
s_find_metro_mode5:
s_find_metro_mode6:
s_find_metro_mode7:
s_find_metro_mode8:
s_find_metro_mode9:
s_find_metro_mode10:
find_map_mode1:
find_map_mode2:
find_map_mode3:
find_map_mode4:
find_indy_mode1:
find_indy_mode2:
find_indy_mode3:
find_indy_mode4:
find_indy_mode5:
find_indy_mode6:
find_indy_mode7:
find_indy_mode8:
find_indy_mode9:
find_indy_mode10:
s_find_indy_mode1:
s_find_indy_mode2:
s_find_indy_mode3:
s_find_indy_mode4:
s_find_indy_mode5:
s_find_indy_mode6:
s_find_indy_mode7:
s_find_indy_mode8:
s_find_indy_mode9:
s_find_indy_mode10:
find_scl_mode1:
find_scl_mode2:
find_scl_mode3:
find_scl_mode4:
find_scl_mode5:
find_scl_mode6:
find_scl_mode7:
find_scl_mode8:
find_scl_mode9:
find_scl_mode10:
s_find_scl_mode1:
s_find_scl_mode2:
s_find_scl_mode3:
s_find_scl_mode4:
s_find_scl_mode5:
s_find_scl_mode6:
s_find_scl_mode7:
s_find_scl_mode8:
s_find_scl_mode9:
s_find_scl_mode10:
find_work_mode1:2_1011_0001_0001
find_work_mode2:2_1011_0001_0003
find_work_mode3:2_1011_0001_0005
find_work_mode4:2_1011_0001_0007
find_work_mode5:2_1011_0001_0006
find_work_mode6:2_1011_0001_0004
find_work_mode7:2_1011_0001_8001
find_work_mode8:
find_work_mode9:
find_work_mode10:
s_find_work_mode1:軟體專案主管
s_find_work_mode2:網路程式設計師
s_find_work_mode3:軟體工程師
s_find_work_mode4:通訊軟體工程師
s_find_work_mode5:演算法開發工程師
s_find_work_mode6:系統規劃分析師
s_find_work_mode7:其他資訊專業人員
s_find_work_mode8:
s_find_work_mode9:
s_find_work_mode10:
find_job_mode1:
find_job_mode2:
find_job_mode3:
find_job_mode4:
find_job_mode5:
find_job_mode6:
find_job_mode7:
find_job_mode8:
find_job_mode9:
find_job_mode10:
s_find_job_mode1:
s_find_job_mode2:
s_find_job_mode3:
s_find_job_mode4:
s_find_job_mode5:
s_find_job_mode6:
s_find_job_mode7:
s_find_job_mode8:
s_find_job_mode9:
s_find_job_mode10:
find_sche_mode1:
find_sche_mode2:
find_sche_mode3:
find_sche_mode4:
find_sche_mode5:
s_find_sche_mode1:
s_find_sche_mode2:
s_find_sche_mode3:
s_find_sche_mode4:
s_find_sche_mode5:
_mu_sf_1:
_mu_se_1:
_mu_chkbox_2:
_mu_chkbox_3:
_mu_wk_1:
_mu_wk_2:
_mu_wk_3:
_mu_wk_4:
_mu_wk_5:
_mu_job_1:
_mu_edu_1:
_mu_edu_2:
_mu_edu_3:
_mu_edu_4:
_mu_edu_5:
_mu_edu_6:
_mu_edu_7:
_mu_year_1:
_mu_year_2:
_mu_lang_1:
_mu_lang_2:
_mu_lang_3:
_mu_psn_1:
_mu_vc_1:
_mu_vc_2:
_mu_vc_3:
_mu_vc_4:
_mu_sc_1:
_mu_sc_2:
find_subj_mode1:
find_subj_mode2:
find_subj_mode3:
s_find_subj_mode1:
s_find_subj_mode2:
s_find_subj_mode3:
find_sw_mode1:
find_sw_mode2:
find_sw_mode3:
find_sw_mode4:
find_sw_mode5:
s_find_sw_mode1:
s_find_sw_mode2:
s_find_sw_mode3:
s_find_sw_mode4:
s_find_sw_mode5:
find_cert_mode1:
find_cert_mode2:
find_cert_mode3:
find_cert_mode4:
find_cert_mode5:
s_find_cert_mode1:
s_find_cert_mode2:
s_find_cert_mode3:
s_find_cert_mode4:
s_find_cert_mode5:
order_by:m_date
order_ascend:desc
strrec:%s
search_key_word:
search_type:job
us_menu:
search_item:1
search_from:joblist
job_show_type:L'''%ii
    data={}
    for line in form_data.split('\n'):
        kv=line.split(':')
        data[kv[0]]=kv[1]


    cookie='''_sh_c_1=search_type%3Ajob%7Csearch_item%3A1%7Cs_find_work_mode1%3A%E8%BB%9F%E9%AB%94%E5%B0%88%E6%A1%88%E4%B8%BB%E7%AE%A1%7Cs_find_work_mode2%3A%E7%B6%B2%E8%B7%AF%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88%E5%B8%AB%7Cs_find_work_mode3%3A%E8%BB%9F%E9%AB%94%E5%B7%A5%E7%A8%8B%E5%B8%AB%7Cs_find_work_mode4%3A%E9%80%9A%E8%A8%8A%E8%BB%9F%E9%AB%94%E5%B7%A5%E7%A8%8B%E5%B8%AB%7Cs_find_work_mode5%3A%E6%BC%94%E7%AE%97%E6%B3%95%E9%96%8B%E7%99%BC%E5%B7%A5%E7%A8%8B%E5%B8%AB%7Cs_find_work_mode6%3A%E7%B3%BB%E7%B5%B1%E8%A6%8F%E5%8A%83%E5%88%86%E6%9E%90%E5%B8%AB%7Cs_find_work_mode7%3A%E5%85%B6%E4%BB%96%E8%B3%87%E8%A8%8A%E5%B0%88%E6%A5%AD%E4%BA%BA%E5%93%A1%7Cfind_work_mode1%3A2_1011_0001_0001%7Cfind_work_mode2%3A2_1011_0001_0003%7Cfind_work_mode3%3A2_1011_0001_0005%7Cfind_work_mode4%3A2_1011_0001_0007%7Cfind_work_mode5%3A2_1011_0001_0006%7Cfind_work_mode6%3A2_1011_0001_0004%7Cfind_work_mode7%3A2_1011_0001_8001%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; ASPSESSIONIDQCATQRSS=FKOEBLOCFAEFDKIGBCIJGPMM; citrix_ns_id=VV0RPI0lJ6FsUA9qXL9QotvFaOYA000; view%5Fjob%5Fid%5Fstr=13690%5F11395000%40%21%4020120614144726%5F9324965%40%21%40Java%E5%B7%A5%E7%A8%8B%E5%B8%AB; _gat=1; yes123_make_cookie=0ee0ea2c28103b3a274da90fab76dd60; ASP.NET_SessionId=783371771; StepCookie_id=783371771; ClientIP=1.160.107.101; __asc=145598fa15d1706fe6d81a4c373; __auc=47f1dbaa15d10ef0098d86b1906; _ga=GA1.3.1671323496.1499227694; _gid=GA1.3.1110029017.1499227694; step=5'''
    cookies={}
    for row in cookie.split(';'):
        ckv=row.split('=')
        cookies[ckv[0]]=ckv[1]
    
    url='https://www.yes123.com.tw/admin/job_refer_list.asp'
    res=requests.post(url,data=data,cookies=cookies)
    print('status:'+str(res.status_code))
    if res.status_code =='200':
        break
    res.encoding='utf8'
#     print(res.text)
    from bs4 import BeautifulSoup as bs
    soup=bs(res.text,"lxml")
    
    res.close
    # soup.select(".selectorgadget_selected")
#     allpage=soup.find(attrs={'align':'right'}).text.split('第1 / ')[1].split('頁')[0]
#     print(allpage+'pages')
    # print(soup.select('a.jobname'))
    # print('----'*10)
    uri = "https://www.yes123.com.tw"
    urls=[job['href'] for job in soup.select('a.jobname')]
    titles=[job['title'] for job in soup.select('a.jobname')]
    #     print(job)
    #     print(job['title']+":"+uri+job['href'])
    joblist=[]
    for title,url in zip(titles,urls):
        jobdict={}
        jobdict['title']=title
        if url[0]=='/':
            jobdict['url']="https://www.yes123.com.tw"+url
        else:
            jobdict['url']="https://www.yes123.com.tw/admin/"+url
        joblist.append(jobdict)
#     print(joblist)
    import os
    if not os.path.exists('yes123'):
        os.makedirs('yes123')
    for job in joblist:
        res2=requests.get(job['url'])
        print(job['url'].split('job_id=')[1].split('@')[0])
        with open('./yes123/'+job['title'].strip().replace("/","_")+job['url'].split('job_id=')[1].split('@')[0],'w') as f:
            f.write(res2.text)
# Out:
# status:200
# 20120614144726_9324965
# 20140911210959_700293
# 20150528130047_25436979
# 20170307134828_23021
# 20170612145405_9881314
# 20170424101427_4126570
# 20170626150740_5276165
# 20170630170734_6723491
# 20170313150345_9857097
# 20150528130047_25436979
# 20110324154508_76943714
# 20160310133933_32764043
# 20160219095830_7549488
# 20130723172300_7245385
# 20170110094831_4137857
# 20130723172252_4512308
# 20150123112158_9018061
# 20170110093457_29434746
# 20170706155846_83786505
# 20170706153650_1012
# 20170706153650_61212403
# 20170706153650_48471
# 20151023195528_13284267
# 20160120155950_16082988
# 20161123152909_51052717
# 20160407110900_13031655
# 20161229184541_29028367
# 20161208123404_21980
# 20170426180445_13937940
# status:200
# 20140911210959_700293
# 20120614144726_9324965
# 20170606172231_481220
# 20160427133934_4450015
# 20100803154100_84646731
# 20170509164708_8082968
# 20130103093144_64527953
# 20170614153920_15704906
# 20170426180445_26873
# ...

# %%
from bs4 import BeautifulSoup as bs
soup=bs(res.text,"lxml")

res.close
# soup.select(".selectorgadget_selected")
allpage=soup.find(attrs={'align':'right'}).text.split('第1 / ')[1].split('頁')[0]
print(allpage)
# print(soup.select('a.jobname'))
# print('----'*10)
uri = "https://www.yes123.com.tw"
urls=[job['href'] for job in soup.select('a.jobname')]
titles=[job['title'] for job in soup.select('a.jobname')]
#     print(job)
#     print(job['title']+":"+uri+job['href'])
joblist=[]
for title,url in zip(titles,urls):
    jobdict={}
    jobdict['title']=title
    if url[0]=='/':
        jobdict['url']="https://www.yes123.com.tw"+url
    else:
        jobdict['url']="https://www.yes123.com.tw/admin/"+url
    joblist.append(jobdict)
# print(joblist)
import os
if not os.path.exists('yes123'):
    os.makedirs('yes123')
for job in joblist:
    res2=requests.get(job['url'])
    with open('./yes123/'+job['url'].split('job_id=')[1].split('@')[0],'w') as f:
        f.write(res2.text)
# Out:
# 42

# %%
datadir ='./yes123/'
file_data = []
from collections import Counter
co=Counter()
for filename in os.listdir(datadir):
    with open(datadir+filename) as jobt:
#         print(jobt.read())
        soup=bs(jobt.read(),'lxml')
#         print(soup)
        for row in soup.select('li'):
#             print(row.text)
#             print("="*50)
            if row.text[:5]=="電腦技能：":
#                 print(row)
#                 print("="*50)
                allskill=row.text[5:].replace('資料庫：','/').replace('網頁技術：','/').replace('網路技術：','/').replace('作業系統：','/')\
                    .replace('伺服器及管理：','/').replace('程式設計：','/').replace('辦公室應用：','/').replace('／','/').replace('\n','/')\
                    .replace('附加條件：','/').replace('\'','/').replace('繪圖軟體：','/').replace(' ','').replace('工程繪圖：','')\
                    .replace('硬體元件設計：','/').replace('\t','/').replace('取得認證：','/').lower().strip('/').strip().split("/")
                for skill in allskill:
#                     print(allskill)
                    if skill in co and skill!='':
                        co[skill]+=1
                    else:
                        co[skill]=1
                    

print(co.most_common(20))
# Out:
# [('java', 107), ('c++', 105), ('mssql', 92), ('c', 89), ('word', 87), ('excel', 86), ('powerpoint', 79), ('html', 68), ('linux', 65), ('c#', 60), ('mysql', 59), ('javascript', 57), ('asp.net', 52), ('oracle', 51), ('php', 50), ('outlook', 48), ('c#.net', 37), ('android', 31), ('jquery', 30), ('windows', 26)]
